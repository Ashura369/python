# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = [i for i in range(1, 11)]
b = np.random.randint(1, 11, size=10).tolist()

# %%
var = sns.load_dataset('penguins')
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(var, x='bill_length_mm')
plt.show()

# %%
sns.displot(var, x='bill_length_mm', bins=60)
plt.show()

# %%
sns.displot(var, x='bill_length_mm', bins=60, kde=True)     # kde - kernal density estimate
plt.show()

# %%
sns.displot(var, x='bill_length_mm', bins=60, kde=True, rug=True)   
plt.show()

# A rug plot gives you a quick visual of the actual data points in your distribution.
# It helps you see where the data is dense or sparse — i.e., where values actually occur.

# %%
sns.displot(var, x='bill_length_mm', bins=60, kde=True, rug=True, log_scale=True)   
plt.show()


"""    
It applies a logarithmic scale to one or both axes, instead of the regular (linear) scale.

Sometimes your data has values spread across many orders of magnitude (for example, 1, 10, 1000, 100000).
In such cases, a linear axis squishes small values and stretches large ones — making patterns hard to see.
Using a log scale spreads out the data more evenly.

"""
# Out:
# '    \nIt applies a logarithmic scale to one or both axes, instead of the regular (linear) scale.\n\nSometimes your data has values spread across many orders of magnitude (for example, 1, 10, 1000, 100000).\nIn such cases, a linear axis squishes small values and stretches large ones — making patterns hard to see.\nUsing a log scale spreads out the data more evenly.\n\n'

# %%
sns.displot(var, y='flipper_length_mm')
plt.show()
