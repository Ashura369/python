# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# --------------------------------------------------------------------
# for reviewing the learning
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score
# --------------------------------------------------------------------

# %%
df = pd.read_excel("employee_performance_data.xlsx")
df
# Out:
#       Employee_ID  Age  Department    Education  Experience_Years  \
# 0               1   59   Marketing     Master's                25
# 1               2   49   Marketing   Bachelor's                19
# 2               3   35       Sales          PhD                27
# 3               4   28          HR     Master's                19
# 4               5   41  Operations  High School                10
# ...           ...  ...         ...          ...               ...
# 4995         4996   36          IT  High School                10
# 4996         4997   25  Operations     Master's                20
# 4997         4998   24     Finance   Bachelor's                20
# 4998         4999   41          HR   Bachelor's                 6
# 4999         5000   34     Finance     Master's                16
#
#       Hours_Worked_Per_Week  Projects_Handled  Training_Score  High_Performer
# 0                        45                 9              44               1
# ...

# %%
x = df[['Experience_Years', 'Hours_Worked_Per_Week', 'Projects_Handled', 'Training_Score']].values
y = df['High_Performer'].values

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.3)

reg = LogisticRegression()
reg.fit(xTrain, yTrain)

yPrediction = reg.predict(xTest)

data = pd.DataFrame({
    'Experience_Years': xTest[:, 0],
    'Hours_Worked_Per_Week': xTest[:, 1],
    'Projects_Handled': xTest[:, 2],
    'Training_Score': xTest[:, 3],
    'ACTUAL OUTPUT': yTest,
    'PREDICTED OUTPUT': yPrediction
})

data
# Out:
#       Experience_Years  Hours_Worked_Per_Week  Projects_Handled  \
# 0                    1                     51                 3
# 1                   19                     54                 3
# 2                   21                     31                 1
# 3                   23                     47                 7
# 4                   31                     45                 1
# ...                ...                    ...               ...
# 1495                16                     40                 8
# 1496                14                     52                 9
# 1497                27                     32                 7
# 1498                25                     45                 3
# 1499                17                     43                14
#
#       Training_Score  ACTUAL OUTPUT  PREDICTED OUTPUT
# 0                 68              0                 0
# 1                 40              0                 0
# ...

# %%
a = np.array([[10, 20, 5, 40]])
ans = reg.predict(a)
ans
# Out:
# array([0])

# %%
# shows the accuracy, the higher the better
print(accuracy_score(yTest, yPrediction))

# How well the model explains variance in the target (regression fit)
print(r2_score(yTest, yPrediction))

# Average absolute difference between actual and predicted values
print(mean_absolute_error(yTest, yPrediction))

# Average squared difference between actual and predicted values, penalizing larger errors
print(mean_squared_error(yTest, yPrediction))
# Out:
# 0.9993333333333333
# 0.9963380604903581
# 0.0006666666666666666
# 0.0006666666666666666
