# %% [markdown]
# # LEARNING PANDAS 1

# %%
import pandas as pd

# only use for structured data, otherwise dont use it
df = pd.read_csv("titanic.csv")         # df (data frame) -- you can put any variable name you want here    
# full form of .csv is "comma separated value"

# df.head()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Doing the same with excel file

# %%
df2 = pd.ExcelFile("titanic.xls")
df2.sheet_names         # will print the names of all the excel sheet present in the given excel sheet
# Out:
# ['titanic', 'survivors']

# %%
df2 = pd.read_excel("titanic.xls", sheet_name="survivors")      # "sheet_name" accesses the sheet available in the given excel file, else it wil throw error
df2
# Out:
#       Names  age   education        from current city character type
# 0      jeet   25     Masters  Naikenpali         BBSR         SHADOW
# 1      aman   22  Graduation  Naikenpali   Naikenpali       CARELESS
# 2  utkalika   19  Graduation  Naikenpali   Naikenpali       CARELESS
# 3    shruti   22  Graduation  Dungripali          SBP    INTELLIGENT
# 4      Anil   29  Graduation  Bhagitikra   Bhagitikra     PERSUASIVE

# %%
df2=pd.read_excel("titanic.xls")
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Readinh website data

# %%
# it automatically tracks down the tebular data

'''
THIS DOWN BELOW IS ALSO ANOTHER WAY OF WRITING THE SAME CODE, IT WILL NOT WORK BCOZ WIKIPEDIA WILL BLOCK THE DEFAULT PYTHON REQUEST (403 FORBIDDEN)

df3 = pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films") 
df3

'''

url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films"
tables = pd.read_html(
    url,
    match="Rank",
    storage_options={"User-Agent": "Mozilla/5.0"}
)

# tables is a list of DataFrames, pick the first one
df3 = tables[0]
# print(df3.head())
# df3.head()      # will show only some of the data from the top of the table, by default it only shows 5 datas at the time
df3.head(10)
# Out:
#   Rank                        Title        Worldwide gross      Language  \
# 0    1                       Dangal  ₹1,968.03–2,200 crore         Hindi
# 1    2  Baahubali 2: The Conclusion        ₹1,810.60 crore  Telugu/Tamil
# 2    3           Pushpa 2: The Rule     ₹1,642–1,800 crore        Telugu
# 3    4                          RRR     ₹1,300–1,387 crore        Telugu
# 4    5               KGF: Chapter 2     ₹1,200–1,250 crore       Kannada
# 5    6                        Jawan        ₹1,148.32 crore         Hindi
# 6    7                      Pathaan        ₹1,050.30 crore         Hindi
# 7    8                Kalki 2898 AD     ₹1,042–1,100 crore        Telugu
# 8    9                       Animal          ₹917.82 crore         Hindi
# 9   10            Bajrangi Bhaijaan   ₹900.90–969.06 crore         Hindi
#
#      Year  Ref.
# 0  2016.0   [b]
# 1  2017.0   [c]
# 2  2024.0   [d]
# 3  2022.0   [e]
# 4  2022.0   [f]
# 5  2023.0  [37]
# 6  2023.0  [38]
# 7  2024.0   [g]
# ...

# %%
print(type(df3))
df3.tail()      # will print some data from below
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Rank                 Title       Worldwide gross Language    Year   Ref.
# 46     47               Dilwale  ₹372.23–376.85 crore    Hindi  2015.0   [ak]
# 47     48  Prem Ratan Dhan Payo  ₹365.46–388.48 crore    Hindi  2015.0   [al]
# 48     49      Pushpa: The Rise            ₹360 crore   Telugu  2021.0  [117]
# 49     50               Tanhaji  ₹358.78–367.65 crore    Hindi  2020.0   [am]
# 50  Hindi                   NaN                   NaN      NaN     NaN    NaN

# %%
url2 = "https://www.theguardian.com/football/datablog/2012/dec/24/world-best-footballers-top-100-list"
tables2 = pd.read_html(
    url,
    # match="Rank",
    storage_options={"User-Agent": "Mozilla/5.0"}
)
df4 = tables2[0]
df4.head()
# Out:
#   Rank                        Title        Worldwide gross      Language  \
# 0    1                       Dangal  ₹1,968.03–2,200 crore         Hindi
# 1    2  Baahubali 2: The Conclusion        ₹1,810.60 crore  Telugu/Tamil
# 2    3           Pushpa 2: The Rule     ₹1,642–1,800 crore        Telugu
# 3    4                          RRR     ₹1,300–1,387 crore        Telugu
# 4    5               KGF: Chapter 2     ₹1,200–1,250 crore       Kannada
#
#      Year Ref.
# 0  2016.0  [b]
# 1  2017.0  [c]
# 2  2024.0  [d]
# 3  2022.0  [e]
# 4  2022.0  [f]
