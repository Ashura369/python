# %% [markdown]
# # 5 - HeatMap (Categorical - Categorical)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")         
flights = sns.load_dataset("flights")  
iris = sns.load_dataset("iris")         
titanic = pd.read_csv("train.csv")  

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# checking how many ppl form Pclass have died and survived
pd.crosstab(titanic['Pclass'], titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
# checking how many ppl survieved from each classes of 1, 2, and 3
pd.crosstab(titanic['Survived'], titanic['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
sns.heatmap(pd.crosstab(titanic['Survived'], titanic['Pclass']))    # converting the above into a heatmap
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
titanic.groupby('Pclass')[['Survived']].mean()*100
# Out:
#          Survived
# Pclass
# 1       62.962963
# 2       47.282609
# 3       24.236253
