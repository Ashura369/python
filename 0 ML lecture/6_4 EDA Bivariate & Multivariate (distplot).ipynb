# %% [markdown]
# # 4 - Distplot (Numerical - Categorical)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")         
flights = sns.load_dataset("flights")  
iris = sns.load_dataset("iris")         
titanic = pd.read_csv("train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.distplot(titanic['Age'])
plt.show()
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\2622049308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'])

# %%
sns.distplot(titanic['Age'], hist=False)
# hist = False will remove the bars behind the curve
plt.show()
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\139792103.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'], hist=False)

# %%
sns.distplot(titanic['Fare'], hist=False,color='red', label='fare')
sns.distplot(titanic['Age'], hist=False, color='green', label='age')
plt.legend()
plt.show()

# the x-axis is shared, but it represents values from both Age and Fare mixed together, not separately scaled.
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\1806641527.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Fare'], hist=False,color='red', label='fare')
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\1806641527.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# we cant use hue in distplot so we will be using a technique where we can put multiple columns
sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False, color='red', label='Did Not Survive')

sns.distplot(titanic[titanic['Survived'] == 1]['Age'], hist=False, color='green', label='Survived')

# add legend and title
plt.legend()        # this shows the label for each color
plt.title('Age Distribution by Survival Status')
plt.show()
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\299635375.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False, color='red', label='Did Not Survive')
# C:\Users\biswa\AppData\Local\Temp\ipykernel_13224\299635375.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
